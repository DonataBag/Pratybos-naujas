# %% [markdown]
# * This script is designed to extract and analyze aperiodic parameters from FOOOF-fitted PSD data.
# * It includes data validation, where data with poor model fit (r-squared < 0.7) is excluded.
# * The script processes data stored in MATLAB files, performs analysis, and saves the results in Excel and MATLAB formats.

# %%
# Importing Necessary Libraries
import os
import numpy as np
import pandas as pd
import scipy.io as spio
from openpyxl import Workbook

# %% [markdown]
# ## Loading the FOOOF-fitted PSD data

# %%
# Specify the directory where the foof parameter MATLAB data files are located
data_dir = r'E:\Analysis\Analysis\FOOOF MAT FILES'
file_list = [file.name for file in os.scandir(data_dir) if file.is_file()]

# %% [markdown]
# ## Identifying Low R-Squared Values
# In this section the script was written to:
# * Extract subjects and channels where the model fit is below the threshold (r-squared < 0.7).
# * Store details of these low r-squared values for inspection.
# * Read channel information from a CSV file and merge with the low r-squared data.
# * Calculate the number of low r-squared channels per subject.
# * Save the data into an Excel file with separate sheets:
#     * For all IDs and channels with r-squared lower than 0.7
#     * Number of channels with low r-squared per subject

# %%
import os
import scipy.io as spio
import pandas as pd

# Define directories
data_dir = r"E:\Analysis\Analysis\FOOOF MAT FILES"  # Update with your actual path
channel_info_path = "channels.csv"  # Update with actual CSV path
output_file = "low_r_squared_results.xlsx"

# Initialize an empty list for low r-squared values
low_rsq = []

# Define the r-squared threshold
rsq_threshold = 0.7

# Get list of .mat files
file_list = [f for f in os.listdir(data_dir) if f.endswith(".mat")]

print(f"Found {len(file_list)} .mat files.")

# Process each MATLAB file
for file_name in file_list:
    print(f"Processing file: {file_name}")
    
    # Load the MATLAB data file
    mat_data = spio.loadmat(os.path.join(data_dir, file_name))
    
    # Extract required data
    if 'ap_params' in mat_data and 'r_squared' in mat_data:
        ap_params = mat_data['ap_params']
        r_squared = mat_data['r_squared']
    else:
        print(f"Skipping {file_name}: Required data missing.")
        continue
    
    print(f"r_squared shape: {r_squared.shape}")
    print(f"r_squared data: {r_squared}")
    
    # Extract subject name
    subject_name = file_name.split('_parameters')[0]
    
    # Iterate over each channel
    num_channels = len(r_squared[0][0])
    print(f"Number of channels: {num_channels}")
    
    for ch in range(num_channels):
        try:
            rsq = r_squared[0][0][ch][0][0]
            print(f"Subject: {subject_name}, Channel: {ch+1}, R-Squared: {rsq}")
            
            if rsq < rsq_threshold:
                low_rsq.append([subject_name, rsq, ch + 1])
        except IndexError as e:
            print(f"Index error for {subject_name}, Channel {ch+1}: {e}")
        except Exception as e:
            print(f"Unexpected error: {e}")

# Convert to DataFrame
low_rsq_df = pd.DataFrame(low_rsq, columns=['Subject_ID', 'R_Squared', 'Channel_Number'])
print(f"Total low r-squared entries found: {len(low_rsq_df)}")
print(low_rsq_df.head())

# Read channel information and merge
channels = pd.read_csv(channel_info_path)
print("Channel info:")
print(channels.head())

channels['Channel_Number'] = range(1, len(channels) + 1)  # Ensure correct channel numbering
low_rsq_df = low_rsq_df.merge(channels, on='Channel_Number', how='left')
print("Merged DataFrame:")
print(low_rsq_df.head())

# Count low r-squared channels per subject
low_rsq_counts = low_rsq_df.groupby('Subject_ID').size().reset_index(name='Low_R_Squared_Count')
print("Low R-Squared Count per Subject:")
print(low_rsq_counts.head())

# Save to Excel
with pd.ExcelWriter(output_file) as writer:
    low_rsq_df.to_excel(writer, sheet_name='Low R-Squared Details', index=False)
    low_rsq_counts.to_excel(writer, sheet_name='Low R-Squared Count', index=False)

print(f"Results saved to {output_file}")
# Out:
# Found 31 .mat files.
# Processing file: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int_parameters.mat
# r_squared shape: (1, 1)
# r_squared data: [[(array([[0.99225385]]), array([[0.98871354]]), array([[0.99334984]]), array([[0.99428557]]), array([[0.99587817]]), array([[0.98766675]]), array([[0.99121832]]), array([[0.99213037]]), array([[0.99557094]]), array([[0.99579609]]), array([[0.98464123]]), array([[0.99218457]]), array([[0.99644538]]), array([[0.99309438]]), array([[0.99597261]]), array([[0.99253871]]), array([[0.99147812]]), array([[0.99718739]]), array([[0.9939352]]), array([[0.98806882]]), array([[0.99303057]]), array([[0.99284071]]), array([[0.99465781]]), array([[0.99292048]]), array([[0.99133218]]), array([[0.98478558]]), array([[0.99505119]]), array([[0.98031783]]), array([[0.99467819]]), array([[0.99031799]]), array([[0.99565324]]), array([[0.99532838]]), array([[0.98494565]]), array([[0.99160918]]), array([[0.99485597]]), array([[0.99470962]]), array([[0.97992728]]), array([[0.99317004]]), array([[0.99583338]]), array([[0.99309449]]), array([[0.99254428]]), array([[0.99455022]]), array([[0.99387318]]), array([[0.98871594]]), array([[0.99649263]]), array([[0.9930469]]), array([[0.99316599]]), array([[0.98889799]]), array([[0.99613883]]), array([[0.99371803]]), array([[0.99073663]]), array([[0.99217835]]), array([[0.99579963]]), array([[0.99568862]]), array([[0.99480673]]), array([[0.99552975]]), array([[0.9828881]]), array([[0.99033894]]), array([[0.99684233]]), array([[0.98008275]]), array([[0.9958004]]), array([[0.98521335]]))]]
# Number of channels: 62
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 1, R-Squared: 0.9922538536676455
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 2, R-Squared: 0.9887135357278645
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 3, R-Squared: 0.9933498373030385
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 4, R-Squared: 0.9942855674622588
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 5, R-Squared: 0.9958781718166769
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 6, R-Squared: 0.9876667487755664
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 7, R-Squared: 0.9912183186197983
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 8, R-Squared: 0.9921303693669895
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 9, R-Squared: 0.9955709361712582
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 10, R-Squared: 0.9957960937088643
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 11, R-Squared: 0.9846412302949191
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 12, R-Squared: 0.9921845729305501
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 13, R-Squared: 0.996445377929995
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 14, R-Squared: 0.9930943837727948
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 15, R-Squared: 0.9959726145545997
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 16, R-Squared: 0.9925387058585143
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 17, R-Squared: 0.9914781224718259
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 18, R-Squared: 0.9971873879566217
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 19, R-Squared: 0.9939351967663578
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 20, R-Squared: 0.9880688150049162
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 21, R-Squared: 0.9930305742954251
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 22, R-Squared: 0.9928407111355415
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 23, R-Squared: 0.994657812432263
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 24, R-Squared: 0.9929204825038047
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 25, R-Squared: 0.9913321823150546
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 26, R-Squared: 0.9847855811410652
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 27, R-Squared: 0.995051187948172
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 28, R-Squared: 0.9803178288213023
# Subject: NCF_201_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel:
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 46, R-Squared: 0.9947959179434497
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 47, R-Squared: 0.9939063509263992
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 48, R-Squared: 0.9940551917798849
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 49, R-Squared: 0.9940348009639343
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 50, R-Squared: 0.9949657116524537
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 51, R-Squared: 0.9949098939556487
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 52, R-Squared: 0.9807002924980318
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 53, R-Squared: 0.9912333817977864
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 54, R-Squared: 0.9912378312518042
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 55, R-Squared: 0.9958729825665239
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 56, R-Squared: 0.9958684385881207
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 57, R-Squared: 0.9933776343255394
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 58, R-Squared: 0.9951378271228526
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 59, R-Squared: 0.9943572787251919
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 60, R-Squared: 0.990287804299362
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 61, R-Squared: 0.9912170024867438
# Subject: NCF_238_R2256_imp_ch_flt1-45_flt50_rejectedarte_ICA_prep_rf_int, Channel: 62, R-Squared: 0.9958553464498883
# Total low r-squared entries found: 0
# Empty DataFrame
# Columns: [Subject_ID, R_Squared, Channel_Number]
# Index: []
# Channel info:
#   Channel_Label  Channel_Number
# 0           Fp1               1
# 1           Fpz               2
# 2           Fp2               3
# 3            F7               4
# 4            F3               5
# Merged DataFrame:
# Empty DataFrame
# Columns: [Subject_ID, R_Squared, Channel_Number, Channel_Label]
# Index: []
# Low R-Squared Count per Subject:
# Empty DataFrame
# Columns: [Subject_ID, Low_R_Squared_Count]
# Index: []
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 79
#      76 print(low_rsq_counts.head())
#      78 # Save to Excel
# ---> 79 with pd.ExcelWriter(output_file) as writer:
#      80     low_rsq_df.to_excel(writer, sheet_name='Low R-Squared Details', index=False)
#      81     low_rsq_counts.to_excel(writer, sheet_name='Low R-Squared Count', index=False)
#
# File ~\miniconda3\envs\test3\Lib\site-packages\pandas\io\excel\_openpyxl.py:61, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      57 from openpyxl.workbook import Workbook
#      59 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 61 super().__init__(
#      62     path,
#      63     mode=mode,
#      64     storage_options=storage_options,
#      65     if_sheet_exists=if_sheet_exists,
#      66     engine_kwargs=engine_kwargs,
#      67 )
#      69 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      70 # the file and later write to it
#      71 if "r+" in self._mode:  # Load from existing workbook
#
# File ~\miniconda3\envs\test3\Lib\site-packages\pandas\io\excel\_base.py:1246, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1242 self._handles = IOHandles(
#    1243     cast(IO[bytes], path), compression={"compression": None}
#    1244 )
#    1245 if not isinstance(path, ExcelWriter):
# -> 1246     self._handles = get_handle(
#    1247         path, mode, storage_options=storage_options, is_text=False
#    1248     )
#    1249 self._cur_sheet = None
#    1251 if date_format is None:
#
# File ~\miniconda3\envs\test3\Lib\site-packages\pandas\io\common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: 'low_r_squared_results.xlsx'

# %%
# Initialize an empty list for low r-squared values
low_rsq = []

# Define the threshold r-squared values
rsq_threshold = 0.7

# Iterate over each MATLAB data file
for file_name in file_list:
    # Load the MATLAB data file
    mat_data = spio.loadmat(os.path.join(data_dir, file_name))
    ap_params = mat_data['ap_params']  # Aperiodic Parameters: offset, exponent
    r_squared = mat_data['r_squared']

    # Get the channel names and subject name from the file name
    channel_names = ap_params.dtype.names
    subject_name = file_name.split('_parameters')[0]

    # Iterate over each channel
    for ch in range(len(channel_names)):
        rsq = r_squared[0][0][ch][0][0]
        if rsq < rsq_threshold:
            # Add details to the low_rsq list
            low_rsq.append([subject_name, rsq, ch+1])

# Convert the list to a DataFrame
low_rsq_df = pd.DataFrame(low_rsq, columns=['Subject_ID', 'R_Squared', 'Channel_Number'])

# Read channel information and merge with low r-squared data
channels = pd.read_csv('channels.csv')  # Update the path accordingly
channels['Channel_Number'] = range(1, 63)  # Assuming 62 channels
channels.head()

# Merging the data
low_rsq_df = low_rsq_df.merge(channels, on='Channel_Number', how='left')
low_rsq_df.head()
# Out:
# Empty DataFrame
# Columns: [Subject_ID, R_Squared, Channel_Number, Channel_Label]
# Index: []

# %%
# Calculating the low r-squared values per person
low_rsq_subjects = low_rsq_df['Subject_ID'].value_counts().reset_index()
low_rsq_subjects.columns = ['Subject_ID', 'Low_Rsq_Channel_Count']
low_rsq_subjects.head()
# Out:
# Empty DataFrame
# Columns: [Subject_ID, Low_Rsq_Channel_Count]
# Index: []

# %%
# Define data frames to be saved
data_frames = {
    'Low_Rsq_Details': low_rsq_df,
    'Low_Rsq_Count_Per_Subject': low_rsq_subjects,
    'Channel_Details': channels,
}

# Save to Excel
excel_file_name = 'low_rsq.xlsx'
with pd.ExcelWriter(excel_file_name) as writer:
    for sheet_name, data_frame in data_frames.items():
        data_frame.to_excel(writer, sheet_name=sheet_name, index=False)

# %% [markdown]
# ## Extracting and Slope and Offset Parameters (Each Subject)
# This part of the script aims to:
# * Calculate median and mean slope and offset values for each subject.
# * Exclude specific subjects and channels as defined.
# * Save the results in Excel and MATLAB formats.

# %% [markdown]
# Mano kodas>

# %%
import numpy as np
import pandas as pd
import scipy.io as sio
import os

# Function to process each MATLAB file and return statistics
def process_file(file_path, rsq_threshold=0.8):
    # Load the .mat file using scipy.io.loadmat
    data = sio.loadmat(file_path)
    
    # Extract variables
    ap_params = data['ap_params']
    r_squared = data['r_squared']
    
    slope = []
    offset = []

    # Iterate over each channel in the data
    for chan in range(len(ap_params[0][0])):  # Assuming ap_params is a 2D structure
        rsq = r_squared[0][0][chan][0][0]  # Access r_squared for the channel
        
        if rsq < rsq_threshold:  # Exclude channels with low r_squared
            continue
        
        off_n_slope = ap_params[0][0][chan][0]  # Extract ap_params (offset, exponent)
        
        # Calculate slope and offset values
        slope_value = off_n_slope[1]  # Slope is the second parameter
        offset_value = off_n_slope[0]  # Offset is the first parameter
        
        # Append to lists
        slope.append(slope_value)
        offset.append(offset_value)
    
    # Calculate summary statistics
    median_slope = np.nanmedian(slope)
    mean_slope = np.nanmean(slope)
    median_offset = np.nanmedian(offset)
    mean_offset = np.nanmean(offset)

    # Return results as a dictionary
    return {
        'file': file_path,
        'median_slope': median_slope,
        'mean_slope': mean_slope,
        'median_offset': median_offset,
        'mean_offset': mean_offset
    }

# Directory where your .mat files are located
data_dir = r'E:\Analysis\Analysis\FOOOF MAT FILES'

# List all the .mat files in the directory
file_list = [file.name for file in os.scandir(data_dir) if file.is_file() and file.name.endswith('.mat')]

# List to store results for each subject
all_results = []

# Iterate over each file (subject) in the file list
for filename in file_list:
    file_path = os.path.join(data_dir, filename)

    # Process the file and get the statistics
    result = process_file(file_path)
    
    # Add the result to the list of all results
    all_results.append(result)

# Create DataFrame from the list of results
df_results = pd.DataFrame(all_results)

# Optionally, if you want to split an 'ID' column into 'group' and 'id':
def split_id_column(df, id_column):
    if id_column not in df.columns:
        raise ValueError(f"The specified id_column '{id_column}' does not exist in the DataFrame.")
    df[['group', 'id']] = df[id_column].str.split('_', expand=True)   
    df = df.drop(id_column, axis=1)
    return df

# Optionally split the 'ID' column, assuming there is an 'ID' column
# df_results = split_id_column(df_results, id_column='ID')

# Save the results to an Excel file
excel_output_path = r'slope_offset_median_mean_results.xlsx'
with pd.ExcelWriter(excel_output_path) as writer:
    df_results.to_excel(writer, sheet_name='results', index=False)

# Save the results in MATLAB format
mat_output_path = r'slope_offset_median_mean_results.mat'
sio.savemat(mat_output_path, mdict={'results': df_results.to_dict(orient='list')})

print(f"Results saved to {excel_output_path} and {mat_output_path}")
# Out:
# Results saved to slope_offset_median_mean_results.xlsx and slope_offset_median_mean_results.mat

# %% [markdown]
# Duotas kodas>

# %%
# Specify the subjects and channels to exclude
excluded_channels = [{'name': '', 'channel': ''}]

# %% [markdown]
# **For Excel format**

# %%
# Create empty lists to store values
slope = []
offset = []

# Iterate over each channel in the data file
for ch, channel in enumerate(channels):
    rsq = r_squared[0][0][ch][0][0]
    off_n_slope = ap_params[0][0][ch][0]

    # Check if the channel should be excluded for the specific subject
    if (any(excluded['name'] == name and excluded['channel'] == channel for excluded in excluded_channels) or rsq < rsq_threshold):
        slope_value = np.nan
        offset_value = np.nan
    else:
        slope_value = off_n_slope[1]
        offset_value = off_n_slope[0]

        # Append values to the list
    offset.append(offset_value)
    slope.append(slope_value)

 # Calculate the median slope value
median_slope = np.nanmedian(slope)
# Calculate the mean slope value
mean_slope = np.nanmean(slope)
# Calculate the median offset value
median_offset = np.nanmedian(offset)
# Calculate the mean offset value
mean_offset = np.nanmean(offset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       8 off_n_slope = ap_params[0][0][ch][0]
#      10 # Check if the channel should be excluded for the specific subject
# ---> 11 if (any(excluded['name'] == name and excluded['channel'] == channel for excluded in excluded_channels) or rsq < rsq_threshold):
#      12     slope_value = np.nan
#      13     offset_value = np.nan
#
# Cell In[8], line 11, in <genexpr>(.0)
#       8 off_n_slope = ap_params[0][0][ch][0]
#      10 # Check if the channel should be excluded for the specific subject
# ---> 11 if (any(excluded['name'] == name and excluded['channel'] == channel for excluded in excluded_channels) or rsq < rsq_threshold):
#      12     slope_value = np.nan
#      13     offset_value = np.nan
#
# NameError: name 'name' is not defined

# %%
import numpy as np

# Initialize empty lists to store values
slope = []
offset = []

# Iterate over each channel in the data file
for ch, channel in enumerate(channels):
    rsq = r_squared[0][0][ch][0][0]
    off_n_slope = ap_params[0][0][ch][0]

    # Check if the channel should be excluded
    if any(excluded['name'] == name and excluded['channel'] == channel for excluded in excluded_channels) or rsq < rsq_threshold:
        # Exclude this channel
        slope_value = np.nan
        offset_value = np.nan
    else:
        # Extract slope and offset values
        slope_value = off_n_slope[1]
        offset_value = off_n_slope[0]

    # Append values to the respective lists
    slope.append(slope_value)
    offset.append(offset_value)

# Calculate summary statistics
median_slope = np.nanmedian(slope)
mean_slope = np.nanmean(slope)
median_offset = np.nanmedian(offset)
mean_offset = np.nanmean(offset)

# Display the results
print(f"Median Slope: {median_slope}")
print(f"Mean Slope: {mean_slope}")
print(f"Median Offset: {median_offset}")
print(f"Mean Offset: {mean_offset}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 13
#      10 off_n_slope = ap_params[0][0][ch][0]
#      12 # Check if the channel should be excluded
# ---> 13 if any(excluded['name'] == name and excluded['channel'] == channel for excluded in excluded_channels) or rsq < rsq_threshold:
#      14     # Exclude this channel
#      15     slope_value = np.nan
#      16     offset_value = np.nan
#
# Cell In[9], line 13, in <genexpr>(.0)
#      10 off_n_slope = ap_params[0][0][ch][0]
#      12 # Check if the channel should be excluded
# ---> 13 if any(excluded['name'] == name and excluded['channel'] == channel for excluded in excluded_channels) or rsq < rsq_threshold:
#      14     # Exclude this channel
#      15     slope_value = np.nan
#      16     offset_value = np.nan
#
# NameError: name 'name' is not defined

# %% [markdown]
# Function to split 'ID' column into 'group' and 'id'

# %%
def split_id_column(df, id_column):
    
    if id_column not in df.columns:
        raise ValueError(f"The specified id_column '{id_column}' does not exist in the DataFrame.")
    df[['group', 'id']] = df[id_column].str.split('_', expand=True)   
    df = df.drop(id_column, axis=1)
    
    return df

# %%
median_mean_slope = split_id_column(median_mean_slope, id_column='ID')
median_mean_offset = split_id_column(median_mean_offset, id_column='ID')
median_mean_slope.head()

# %%
# Save median and mean slope and offset to excel 
with pd.ExcelWriter('slope_offset_median_mean.xlsx') as writer:
    median_mean_slope.to_excel(writer, sheet_name='median_mean_slope', index=False)
    median_mean_offset.to_excel(writer, sheet_name='median_mean_offset', index=False)

# %% [markdown]
# **For Matlab matrix format**

# %%
# DFs to store values
median_mean_slope = pd.DataFrame(columns=['ID', 'median_slope', 'mean_slope'])
median_mean_offset = pd.DataFrame(columns=['ID', 'median_offset', 'mean_offset'])

# Empty matrix to store the slope and offset values
slopes_matrix = np.empty((len(file_list), len(channels)))
offsets_matrix = np.empty((len(file_list), len(channels)))

# Iterate over each MATLAB data file
for i, file_name in enumerate(file_list):
    # Load the MATLAB data file
    mat_data = spio.loadmat(os.path.join(data_dir, file_name))
    ap_params = mat_data['ap_params']
    r_squared = mat_data['r_squared']

    # Get the channel names and subject name from the file name
    channels = ap_params.dtype.names
    name = file_name.split('_parameters')[0]

    # Create empty lists to store values
    slope = []
    offset = []

    # Iterate over each channel in the data file
    for ch, channel in enumerate(channels):
        rsq = r_squared[0][0][ch][0][0]
        off_n_slope = ap_params[0][0][ch][0]

        # Check if the channel should be excluded for the specific subject
        if (any(excluded['name'] == name and excluded['channel'] == channel for excluded in excluded_channels) or rsq < rsq_threshold):
            slope_value = np.nan
            offset_value = np.nan
        else:
            slope_value = off_n_slope[1]
            offset_value = off_n_slope[0]

        # Append values to the list
        offset.append(offset_value)
        slope.append(slope_value)
        slopes_matrix[i, ch] = slope_value
        offsets_matrix[i, ch] = offset_value

    # Calculate the median slope value
    median_slope = np.nanmedian(slope)
    # Calculate the mean slope value
    mean_slope = np.nanmean(slope)
    # Calculate the median offset value
    median_offset = np.nanmedian(offset)
    # Calculate the mean offset value
    mean_offset = np.nanmean(offset)

    # Update the median_mean_slope DataFrame with the subject's ID and slope values
    median_mean_slope.at[i, 'ID'] = name
    median_mean_slope.at[i, 'median_slope'] = median_slope
    median_mean_slope.at[i, 'mean_slope'] = mean_slope
    
    # Update the median_mean_offset DataFrame with the subject's ID and offset values
    median_mean_offset.at[i, 'ID'] = name
    median_mean_offset.at[i, 'median_offset'] = median_offset
    median_mean_offset.at[i, 'mean_offset'] = mean_offset

# %%
# Save slope and offset matrixes to matlab structure

data = {'slopes_matrix': slopes_matrix,
        'offsets_matrix': offsets_matrix}

spio.savemat('slope_off_matrix.mat', data)

# %% [markdown]
# ## Median and Mean Values by Group and Channel
# * The following section creates DataFrames for each subject and channel, categorizing them into groups based on subject ID.
# * It calculates median values for slopes and offsets for each group/group and channel.
# * The results are saved in an Excel file with multiple sheets.

# %%
# Create the DataFrame with slope values and modify the index values
slope_ch_id = pd.DataFrame(slopes_matrix, columns=channels, index=[int(''.join(filter(str.isdigit, name.split('_parameters')[0]))) for name in file_list])

# Create the DataFrame with offset values and modify the index values
offset_ch_id = pd.DataFrame(offsets_matrix, columns=channels, index=[int(''.join(filter(str.isdigit, name.split('_parameters')[0]))) for name in file_list])

# %%
# Reset the index and rename the column
slope_ch_id = slope_ch_id.reset_index().rename(columns={'index': 'id'})

offset_ch_id = offset_ch_id.reset_index().rename(columns={'index': 'id'})

# Create a mapping dictionary for the 'group' column
group_mapping = {
    (0, 100): 'OC',
    (100, 200): 'IUD',
    (200, 300): 'NCF',
    (300, 400): 'NCL',
    (400, float('inf')): 'M',
}

# Add the 'group' column based on ID values for slope_ch_id DataFrame
slope_ch_id.insert(1, 'group', pd.cut(slope_ch_id['id'], bins=[0, 100, 200, 300, 400, float('inf')], labels=['OC', 'IUD', 'NCF', 'NCL', 'M']))

# Add the 'group' column based on ID values for offset_ch_id DataFrame
offset_ch_id.insert(1, 'group', pd.cut(offset_ch_id['id'], bins=[0, 100, 200, 300, 400, float('inf')], labels=['OC', 'IUD', 'NCF', 'NCL', 'M']))

# %% [markdown]
# Median slope and offset values for each group and channel

# %%
# Create DataFrames with slope and offset values, indexed by subject ID
slope_df = pd.DataFrame(slopes_matrix, columns=channels, index=[int(''.join(filter(str.isdigit, name.split('_parameters')[0]))) for name in file_list])
offset_df = pd.DataFrame(offsets_matrix, columns=channels, index=[int(''.join(filter(str.isdigit, name.split('_parameters')[0]))) for name in file_list])

# Reset the index and rename the column
slope_df = slope_df.reset_index().rename(columns={'index': 'ID'})
offset_df = offset_df.reset_index().rename(columns={'index': 'ID'})

# Define groups based on subject IDs
group_labels = ['OC', 'IUD', 'NCF', 'NCL', 'M']
group_bins = [0, 100, 200, 300, 400, float('inf')]

# Assign groups to DataFrames
slope_df.insert(1, 'Group', pd.cut(slope_df['ID'], bins=group_bins, labels=group_labels))
offset_df.insert(1, 'Group', pd.cut(offset_df['ID'], bins=group_bins, labels=group_labels))

# Calculate median values for each subject and group
median_slope = slope_df.groupby('Group').median()
median_offset = offset_df.groupby('Group').median()

# %%
# Save to Excel
excel_file = 'Slope_offset.xlsx'
with pd.ExcelWriter(excel_file) as writer:
    slope_df.to_excel(writer, sheet_name='Slope_Subject_Channel', index=False)
    offset_df.to_excel(writer, sheet_name='Offset_Subject_Channel', index=False)
    median_slope.to_excel(writer, sheet_name='Median_Slope_by_Group_Channel', index=False)
    median_offset.to_excel(writer, sheet_name='Median_Offset_by_Group_Channel', index=False)
